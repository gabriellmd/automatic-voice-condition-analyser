# %%
import pandas as pd
from tensorflow.keras import layers, models, regularizers
import numpy as np
from sklearn.model_selection import train_test_split, KFold
import pickle
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_curve, auc
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from tensorflow.keras import backend as K

# %%
path_csvs = "D:/mestrado/notebooks/dados/features_csv"
cols_to_scale = ['RMSE', 'ZCR', 'COEF_1', 'COEF_2', 'COEF_3', 'COEF_4', 'COEF_5', 'COEF_6', 'COEF_7', 'COEF_8', 'COEF_9', 'COEF_10', 'COEF_11', 'COEF_12', 'COEF_13', 'COEF_14', 'COEF_15', 'COEF_16', 'COEF_17', 'COEF_18', 'COEF_19', 'COEF_20']

# %%
df_masculino_completo_normalizado = pd.read_csv("D:/mestrado/notebooks/dados/features_csv/masculino_completo_normalizado.csv", sep=";")

# %% [markdown]
# ### Criando Tensor

# %%
def dataframe_to_tensor(df, num_features):
    grouped = df.groupby("Audio")
    # Cria uma lista de arrays, um para cada áudio
    tensors = [group.iloc[:, :num_features].values for _, group in grouped]
    return np.array(tensors)  # Converte para um tensor 3D

# %%
# Função para padronizar as sequências (com padding ou truncamento)
def standardize_frames(sequences, max_frames):
    standardized_sequences = []
    for seq in sequences:
        if len(seq) < max_frames:
            # Padding: Adiciona zeros ao final da sequência
            padded_seq = np.pad(seq, ((0, max_frames - len(seq)), (0, 0)), mode='constant')
            standardized_sequences.append(padded_seq)
        else:
            # Truncamento: Corta a sequência para o tamanho máximo
            truncated_seq = seq[:max_frames, :]
            standardized_sequences.append(truncated_seq)
    return np.array(standardized_sequences)

# %%
grouped = df_masculino_completo_normalizado.groupby("Audio")
df_frames = pd.DataFrame()
df_frames['frames'] = df_masculino_completo_normalizado.groupby("Audio").size()

# %%
df_frames.head()
print(df_frames['frames'].sum())
numero_max_frames = int(df_frames['frames'].mean())
# Out:
# 214221

# %%
def extract_y(df):
    num_features = 23  # RMS (1) + ZCR (1) + 20 MFCCs
    grouped = df.groupby("Audio")

    # Converta cada áudio para uma matriz (frames x features)
    sequences = [group.iloc[:, :num_features].values for _, group in grouped]

    # Padronize os frames
    max_frames = numero_max_frames  # Defina o número fixo de frames
    tensor = standardize_frames(sequences, max_frames)

    print("Shape do tensor:", tensor.shape)  # Deve ser (num_audios, max_frames, num_features)

    y = []
    for s in sequences:
        for element in s[0]:
            if isinstance(element, str): 
                if 'saudavel' in element:
                        y.append(0)
                else:
                    y.append(1)
                break

    print(len(y))

    return np.array(y)

# %%
def extract_tensor_x(df):
    num_features = 22  # RMS (1) + ZCR (1) + 20 MFCCs
    # Agrupe o DataFrame por áudio
    grouped = df.groupby("Audio")

    # Converta cada áudio para uma matriz (frames x features)
    sequences = [group.iloc[:, :num_features].values for _, group in grouped]

    # Padronize os frames
    max_frames = numero_max_frames  # Defina o número fixo de frames
    tensor = standardize_frames(sequences, max_frames)

    print("Shape do tensor:", tensor.shape)  # Deve ser (num_audios, max_frames, num_features)
    return tensor

# %% [markdown]
# ### Criando a Rede Neural

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def generate_model():
    # Dimensão das features (exemplo: 20 MFCCs + RMS + ZCR -> 22 features por timestep)
    input_shape = (None, 22)  # None -> Sequência variável, 22 -> Features por timestep

    # Regularização L2 (lambda = 0.01)
    l2_reg = regularizers.L2(0.01)

    # Entrada
    inputs = layers.Input(shape=input_shape)

    # 5 Blocos CNN
    x = inputs
    for _ in range(5):
        x = layers.Conv1D(64, kernel_size=3, padding="same", activation="relu", kernel_regularizer=l2_reg)(x)
        x = layers.BatchNormalization()(x)
        x = layers.MaxPooling1D(pool_size=2)(x)
        x = layers.Dropout(0.3)(x)  # Dropout adicional

    # LSTM com regularização L2
    x = layers.LSTM(128, return_sequences=True, kernel_regularizer=l2_reg)(x)

    # Camada de Atenção
    attention = layers.Dense(1, activation="tanh", kernel_regularizer=l2_reg)(x)  # Escore de atenção
    attention = layers.Flatten()(attention)  # Remove dimensão extra
    attention = layers.Activation("softmax")(attention)  # Probabilidade
    attention = layers.RepeatVector(128)(attention)  # Ajusta dimensão para aplicar
    attention = layers.Permute([2, 1])(attention)  # Transposição

    x = layers.Multiply()([x, attention])  # Aplicação da atenção
    x = layers.LSTM(128, kernel_regularizer=l2_reg)(x)  # Resumo da sequência com LSTM final

    # Camadas densas para classificação com regularização e Dropout
    x = layers.Dense(64, activation="relu", kernel_regularizer=l2_reg)(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(1, activation="sigmoid", kernel_regularizer=l2_reg)(x)  # Saída binária

    # Construção do modelo
    model = models.Model(inputs, outputs)

    # Compilação
    # Learning Rate default do Adam = 0.001
    model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy", "binary_accuracy", "precision", "recall"])
    return model

# Resumo do modelo
model_cnn_rnn = generate_model()
model_cnn_rnn.summary()
# Out:
# Model: "functional_22"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_22      │ (None, None, 22)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_120 (Conv1D) │ (None, None, 64)  │      4,288 │ input_layer_22[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None, 64)  │        256 │ conv1d_120[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_90    │ (None, None, 64)  │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_142         │ (None, None, 64)  │          0 │ max_pooling1d_90… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_121 (Conv1D) │ (None, None, 64)  │     12,352 │ dropout_142[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None, 64)  │        256 │ conv1d_121[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_91    │ (None, None, 64)  │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_143         │ (None, None, 64)  │          0 │ max_pooling1d_91… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_122 (Conv1D) │ (None, None, 64)  │     12,352 │ dropout_143[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None, 64)  │        256 │ conv1d_122[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_92    │ (None, None, 64)  │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_144         │ (None, None, 64)  │          0 │ max_pooling1d_92… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_123 (Conv1D) │ (None, None, 64)  │     12,352 │ dropout_144[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None, 64)  │        256 │ conv1d_123[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_93    │ (None, None, 64)  │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_145         │ (None, None, 64)  │          0 │ max_pooling1d_93… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_124 (Conv1D) │ (None, None, 64)  │     12,352 │ dropout_145[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, None, 64)  │        256 │ conv1d_124[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_94    │ (None, None, 64)  │          0 │ batch_normalizat… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_146         │ (None, None, 64)  │          0 │ max_pooling1d_94… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_44 (LSTM)      │ (None, None, 128) │     98,816 │ dropout_146[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_66 (Dense)    │ (None, None, 1)   │        129 │ lstm_44[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_12          │ (None, None)      │          0 │ dense_66[0][0]    │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, None)      │          0 │ flatten_12[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_vector_12    │ (None, 128, None) │          0 │ activation_12[0]… │
# │ (RepeatVector)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_12          │ (None, None, 128) │          0 │ repeat_vector_12… │
# │ (Permute)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_22         │ (None, None, 128) │          0 │ lstm_44[0][0],    │
# │ (Multiply)          │                   │            │ permute_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_45 (LSTM)      │ (None, 128)       │    131,584 │ multiply_22[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_67 (Dense)    │ (None, 64)        │      8,256 │ lstm_45[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_147         │ (None, 64)        │          0 │ dense_67[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_68 (Dense)    │ (None, 1)         │         65 │ dropout_147[0][0] │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 293,826 (1.12 MB)
#  Trainable params: 293,186 (1.12 MB)
#  Non-trainable params: 640 (2.50 KB)

# %%
# dividindo tensor entre treino, validação e teste
X = extract_tensor_x(df_masculino_completo_normalizado)
y = extract_y(df_masculino_completo_normalizado)

assert len(y) == 2000
assert X.shape[0] == len(y)
# Out:
# Shape do tensor: (2000, 107, 22)
# Shape do tensor: (2000, 107, 23)
# 2000

# %%
reduce_lr = ReduceLROnPlateau(
    monitor="loss",  # Monitorar a perda da validação
    factor=0.5,  # Reduz o LR pela metade
    patience=3,  # Espera 3 épocas sem melhora antes de reduzir
    min_lr=1e-6,  # LR mínimo para evitar valores muito pequenos
    verbose=1  # Exibir mensagens quando o LR for reduzido
)

# %% [markdown]
# ### 10-fold cross-validation

# %%
# Geração de dados simulados (substitua pelos seus dados)
np.random.seed(42)

# Parâmetros
k = 10  # Número de folds
num_epochs = 20
batch_size = 32
test_size = 0.3  # Porcentagem para o conjunto de teste

train_accuracies = np.zeros((k, num_epochs))
val_accuracies = np.zeros((k, num_epochs))

# Dividindo os dados em treino+validação e teste
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

# Configurando o K-Fold
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Lista para armazenar as métricas de cada fold
fold_losses = []
fold_accuracies = []
fold_binary_accuracies = []
fold_precisions = []
fold_recalls = []
fold_f1_scores = []
histories = []

# k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(kf.split(X_train_val)):
    print(f"\nFold {fold+1}/{k}")
    
    # Dividindo os índices para treino e validação
    X_train, X_val = X_train_val[train_idx], X_train_val[val_idx]
    y_train, y_val = y_train_val[train_idx], y_train_val[val_idx]
    
    # Criando o modelo
    model = generate_model()
    
    # Early stopping para evitar overfitting
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Configuração do ModelCheckpoint
    checkpoint_callback = ModelCheckpoint(
        filepath='/checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras',      # Caminho onde o modelo será salvo
        monitor='val_loss',               # Métrica monitorada (ex: val_loss ou val_accuracy)
        save_best_only=True,              # Salva apenas o melhor modelo
        save_weights_only=False,          # Salva o modelo completo, incluindo arquitetura
        mode='min',                       # Modo de monitoramento (min para loss, max para accuracy)
        verbose=1                         # Exibe mensagens quando o modelo é salvo
    )
    
    # Treinando o modelo
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=num_epochs,
        batch_size=batch_size,
        callbacks=[early_stopping, checkpoint_callback],
        verbose=1
    )

    # Salvar as acurácias
    train_accuracies[fold] = history.history['accuracy']
    val_accuracies[fold] = history.history['val_accuracy']
    
    # Avaliando no conjunto de validação
    val_loss, val_accuracy, val_binary_accuracy, val_precision, val_recall = model.evaluate(X_val, y_val, verbose=1)
    print(f"Validação - Loss: {val_loss:.4f}, Accuracy: {val_accuracy:.4f}")
    fold_accuracies.append(val_accuracy)
    fold_losses.append(val_loss)
    fold_binary_accuracies.append(val_binary_accuracy)
    fold_precisions.append(val_precision)
    fold_recalls.append(val_recall)
    #fold_f1_scores.append(val_f1_score)
    histories.append(history)

# Avaliação final no conjunto de treino
print("\nCross-validation completado.")
print(f"Accuracies por fold: {fold_accuracies}")
print(f"Accuracy média: {np.mean(fold_accuracies):.4f}, Desvio padrão: {np.std(fold_accuracies):.4f}")
# Out:
# Fold 1/10
# Epoch 1/20
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5673 - binary_accuracy: 0.5673 - loss: 6.2949 - precision: 0.5483 - recall: 0.7612
# Epoch 1: val_loss improved from inf to 3.03788, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.5828 - binary_accuracy: 0.5828 - loss: 6.1719 - precision: 0.5604 - recall: 0.7706 - val_accuracy: 0.5000 - val_binary_accuracy: 0.5000 - val_loss: 3.0379 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9496 - binary_accuracy: 0.9496 - loss: 2.2680 - precision: 0.9599 - recall: 0.9388
# Epoch 2: val_loss improved from 3.03788 to 1.73295, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9506 - binary_accuracy: 0.9506 - loss: 2.2140 - precision: 0.9604 - recall: 0.9401 - val_accuracy: 0.5000 - val_binary_accuracy: 0.5000 - val_loss: 1.7330 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9779 - binary_accuracy: 0.9779 - loss: 1.0479 - precision: 0.9714 - recall: 0.9824
# Epoch 3: val_loss improved from 1.73295 to 1.21561, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9780 - binary_accuracy: 0.9780 - loss: 1.0425 - precision: 0.9716 - recall: 0.9823 - val_accuracy: 0.6571 - val_binary_accuracy: 0.6571 - val_loss: 1.2156 - val_precision: 1.0000 - val_recall: 0.3143
# Epoch 4/20
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9775 - binary_accuracy: 0.9775 - loss: 0.6998 - precision: 0.9636 - recall: 0.9896
# Epoch 4: val_loss improved from 1.21561 to 0.86987, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9774 - binary_accuracy: 0.9774 - loss: 0.6980 - precision: 0.9637 - recall: 0.9895 - val_accuracy: 0.9214 - val_binary_accuracy: 0.9214 - val_loss: 0.8699 - val_precision: 1.0000 - val_recall: 0.8429
# Epoch 5/20
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9751 - binary_accuracy: 0.9751 - loss: 0.5463 - precision: 0.9770 - recall: 0.9699
# Epoch 5: val_loss improved from 0.86987 to 0.66378, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9757 - binary_accuracy: 0.9757 - loss: 0.5431 - precision: 0.9776 - recall: 0.9707 - val_accuracy: 0.9714 - val_binary_accuracy: 0.9714 - val_loss: 0.6638 - val_precision: 1.0000 - val_recall: 0.9429
# Epoch 6/20
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9981 - binary_accuracy: 0.9981 - loss: 0.3976 - precision: 0.9992 - recall: 0.9969
# Epoch 6: val_loss did not improve from 0.66378
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9977 - binary_accuracy: 0.9977 - loss: 0.3975 - precision: 0.9989 - recall: 0.9963 - val_accuracy: 0.9429 - val_binary_accuracy: 0.9429 - val_loss: 0.6683 - val_precision: 0.8974 - val_recall: 1.0000
# Epoch 7/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - binary_accuracy: 0.9892 - loss: 0.3547 - precision: 0.9846 - recall: 0.9940
# Epoch 7: val_loss did not improve from 0.66378
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9890 - binary_accuracy: 0.9890 - loss: 0.3552 - precision: 0.9846 - recall: 0.9935 - val_accuracy: 0.5429 - val_binary_accuracy: 0.5429 - val_loss: 0.7867 - val_precision: 0.5224 - val_recall: 1.0000
# Epoch 8/20
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.
- val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9743 - binary_accuracy: 0.9743 - loss: 0.7283 - precision: 0.9702 - recall: 0.9767
# Epoch 4: val_loss improved from 1.70892 to 1.05209, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9742 - binary_accuracy: 0.9742 - loss: 0.7273 - precision: 0.9701 - recall: 0.9768 - val_accuracy: 0.6500 - val_binary_accuracy: 0.6500 - val_loss: 1.0521 - val_precision: 1.0000 - val_recall: 0.3467
# Epoch 5/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9950 - binary_accuracy: 0.9950 - loss: 0.5391 - precision: 0.9941 - recall: 0.9955
# Epoch 5: val_loss did not improve from 1.05209
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9945 - binary_accuracy: 0.9945 - loss: 0.5369 - precision: 0.9937 - recall: 0.9950 - val_accuracy: 0.4643 - val_binary_accuracy: 0.4643 - val_loss: 1.2613 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9792 - binary_accuracy: 0.9792 - loss: 0.4739 - precision: 0.9808 - recall: 0.9772
# Epoch 6: val_loss improved from 1.05209 to 0.58123, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9784 - binary_accuracy: 0.9784 - loss: 0.4748 - precision: 0.9796 - recall: 0.9765 - val_accuracy: 0.9500 - val_binary_accuracy: 0.9500 - val_loss: 0.5812 - val_precision: 1.0000 - val_recall: 0.9067
# Epoch 7/20
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9892 - binary_accuracy: 0.9892 - loss: 0.3930 - precision: 0.9885 - recall: 0.9890
# Epoch 7: val_loss improved from 0.58123 to 0.43596, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9895 - binary_accuracy: 0.9895 - loss: 0.3916 - precision: 0.9888 - recall: 0.9892 - val_accuracy: 0.9929 - val_binary_accuracy: 0.9929 - val_loss: 0.4360 - val_precision: 1.0000 - val_recall: 0.9867
# Epoch 8/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9795 - binary_accuracy: 0.9795 - loss: 0.4084 - precision: 0.9682 - recall: 0.9904
# Epoch 8: val_loss did not improve from 0.43596
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9792 - binary_accuracy: 0.9792 - loss: 0.4080 - precision: 0.9684 - recall: 0.9895 - val_accuracy: 0.8929 - val_binary_accuracy: 0.8929 - val_loss: 0.5399 - val_precision: 1.0000 - val_recall: 0.8000
# Epoch 9/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9874 - binary_accuracy: 0.9874 - loss: 0.3459 - precision: 0.9785 - recall: 0.9965
# Epoch 9: val_loss did not improve from 0.43596
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9868 - binary_accuracy: 0.9868 - loss: 0.3467 - precision: 0.9785 - recall: 0.9951 - val_accuracy: 0.8214 - val_binary_accuracy: 0.8214 - val_loss: 0.6778 - val_precision: 1.0000 - val_recall: 0.6667
# Epoch 10/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9829 - binary_accuracy: 0.9829 - loss: 0.3399 - precision: 0.9860 - recall: 0.9790
# Epoch 10: val_loss improved from 0.43596 to 0.40083, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9824 - binary_accuracy: 0.9824 - loss: 0.3420 - precision: 0.9855 - recall: 0.9783 - val_accuracy: 0.9500 - val_binary_accuracy: 0.9500 - val_loss: 0.4008 - val_precision: 1.0000 - val_recall: 0.9067
# Epoch 11/20
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9761 - binary_accuracy: 0.9761 - loss: 0.3439 - precision: 0.9847 - recall: 0.9665
# Epoch 11: val_loss improved from 0.40083 to 0.27789, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9768 - binary_accuracy: 0.9768 - loss: 0.3424 - precision: 0.9847 - recall: 0.9680 - val_accuracy: 1.0000 - val_binary_accuracy: 1.0000 - val_loss: 0.2779 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 12/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9865 - binary_accuracy: 0.9865 - loss: 0.3004 - precision: 0.9855 - recall: 0.9879
# Epoch 12: val_loss improved from 0.27789 to 0.27365, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.

# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - binary_accuracy: 1.0000 - loss: 0.1760 - precision: 1.0000 - recall: 1.0000
# Validação - Loss: 0.1759, Accuracy: 1.0000
#
# Fold 4/10
# Epoch 1/20
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7369 - binary_accuracy: 0.7369 - loss: 6.2851 - precision: 0.7118 - recall: 0.7603
# Epoch 1: val_loss improved from inf to 3.36013, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - accuracy: 0.7439 - binary_accuracy: 0.7439 - loss: 6.1929 - precision: 0.7206 - recall: 0.7648 - val_accuracy: 0.4929 - val_binary_accuracy: 0.4929 - val_loss: 3.3601 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9660 - binary_accuracy: 0.9660 - loss: 2.3584 - precision: 0.9710 - recall: 0.9641
# Epoch 2: val_loss improved from 3.36013 to 2.17572, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9662 - binary_accuracy: 0.9662 - loss: 2.3143 - precision: 0.9701 - recall: 0.9648 - val_accuracy: 0.4929 - val_binary_accuracy: 0.4929 - val_loss: 2.1757 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9844 - binary_accuracy: 0.9844 - loss: 1.2275 - precision: 0.9823 - recall: 0.9863
# Epoch 3: val_loss improved from 2.17572 to 1.85315, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9844 - binary_accuracy: 0.9844 - loss: 1.2218 - precision: 0.9822 - recall: 0.9862 - val_accuracy: 0.4929 - val_binary_accuracy: 0.4929 - val_loss: 1.8531 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9838 - binary_accuracy: 0.9838 - loss: 0.8553 - precision: 0.9879 - recall: 0.9787
# Epoch 4: val_loss improved from 1.85315 to 1.33557, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9832 - binary_accuracy: 0.9832 - loss: 0.8530 - precision: 0.9870 - recall: 0.9782 - val_accuracy: 0.5071 - val_binary_accuracy: 0.5071 - val_loss: 1.3356 - val_precision: 1.0000 - val_recall: 0.0282
# Epoch 5/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9912 - binary_accuracy: 0.9912 - loss: 0.6589 - precision: 0.9905 - recall: 0.9920
# Epoch 5: val_loss improved from 1.33557 to 1.29531, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9903 - binary_accuracy: 0.9903 - loss: 0.6577 - precision: 0.9888 - recall: 0.9917 - val_accuracy: 0.5214 - val_binary_accuracy: 0.5214 - val_loss: 1.2953 - val_precision: 1.0000 - val_recall: 0.0563
# Epoch 6/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9934 - binary_accuracy: 0.9934 - loss: 0.5402 - precision: 0.9914 - recall: 0.9952
# Epoch 6: val_loss improved from 1.29531 to 0.94182, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9933 - binary_accuracy: 0.9933 - loss: 0.5401 - precision: 0.9913 - recall: 0.9951 - val_accuracy: 0.7071 - val_binary_accuracy: 0.7071 - val_loss: 0.9418 - val_precision: 1.0000 - val_recall: 0.4225
# Epoch 7/20
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9883 - binary_accuracy: 0.9883 - loss: 0.4776 - precision: 0.9951 - recall: 0.9819
# Epoch 7: val_loss improved from 0.94182 to 0.80756, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9884 - binary_accuracy: 0.9884 - loss: 0.4762 - precision: 0.9945 - recall: 0.9826 - val_accuracy: 0.7929 - val_binary_accuracy: 0.7929 - val_loss: 0.8076 - val_precision: 1.0000 - val_recall: 0.5915
# Epoch 8/20
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9911 - binary_accuracy: 0.9911 - loss: 0.4024 - precision: 0.9976 - recall: 0.9846
# Epoch 8: val_loss improved from 0.80756 to 0.51635, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9913 - binary_accuracy: 0.9913 - loss: 0.4015 - precision: 0.9974 - recall: 0.9851 - val_accuracy: 0.9214 - val_binary_accuracy: 0.9214 - val_loss: 0.5163 - val_precision: 1.0000 - val_recall: 0.8451
# Epoch 9/20
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9888 - binary_accuracy: 0.9888 - loss: 0.2714 - precision: 0.9900 - recall: 0.9873
# Epoch 17: val_loss improved from 0.26694 to 0.25106, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9888 - binary_accuracy: 0.9888 - loss: 0.2717 - precision: 0.9898 - recall: 0.9874 - val_accuracy: 0.9929 - val_binary_accuracy: 0.9929 - val_loss: 0.2511 - val_precision: 0.9861 - val_recall: 1.0000
# Epoch 18/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9995 - binary_accuracy: 0.9995 - loss: 0.2194 - precision: 0.9990 - recall: 1.0000
# Epoch 18: val_loss improved from 0.25106 to 0.24513, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9995 - binary_accuracy: 0.9995 - loss: 0.2193 - precision: 0.9989 - recall: 1.0000 - val_accuracy: 0.9857 - val_binary_accuracy: 0.9857 - val_loss: 0.2451 - val_precision: 0.9859 - val_recall: 0.9859
# Epoch 19/20
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9932 - binary_accuracy: 0.9932 - loss: 0.2257 - precision: 0.9949 - recall: 0.9914
# Epoch 19: val_loss improved from 0.24513 to 0.23282, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9931 - binary_accuracy: 0.9931 - loss: 0.2254 - precision: 0.9948 - recall: 0.9914 - val_accuracy: 0.9929 - val_binary_accuracy: 0.9929 - val_loss: 0.2328 - val_precision: 0.9861 - val_recall: 1.0000
# Epoch 20/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9896 - binary_accuracy: 0.9896 - loss: 0.2260 - precision: 0.9833 - recall: 0.9952
# Epoch 20: val_loss improved from 0.23282 to 0.21869, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9898 - binary_accuracy: 0.9898 - loss: 0.2252 - precision: 0.9840 - recall: 0.9950 - val_accuracy: 0.9857 - val_binary_accuracy: 0.9857 - val_loss: 0.2187 - val_precision: 0.9859 - val_recall: 0.9859
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9866 - binary_accuracy: 0.9866 - loss: 0.2145 - precision: 0.9894 - recall: 0.9845
# Validação - Loss: 0.2187, Accuracy: 0.9857
#
# Fold 5/10
# Epoch 1/20
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5936 - binary_accuracy: 0.5936 - loss: 6.2453 - precision: 0.6188 - recall: 0.3271
# Epoch 1: val_loss improved from inf to 3.04663, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.6008 - binary_accuracy: 0.6008 - loss: 6.1861 - precision: 0.6303 - recall: 0.3392 - val_accuracy: 0.5643 - val_binary_accuracy: 0.5643 - val_loss: 3.0466 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9545 - binary_accuracy: 0.9545 - loss: 2.2677 - precision: 0.9504 - recall: 0.9560
# Epoch 2: val_loss improved from 3.04663 to 1.68071, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9560 - binary_accuracy: 0.9560 - loss: 2.2138 - precision: 0.9523 - recall: 0.9574 - val_accuracy: 0.5929 - val_binary_accuracy: 0.5929 - val_loss: 1.6807 - val_precision: 1.0000 - val_recall: 0.0656
# Epoch 3/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9867 - binary_accuracy: 0.9867 - loss: 1.0348 - precision: 0.9827 - recall: 0.9901
# Epoch 3: val_loss improved from 1.68071 to 1.12662, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9867 - binary_accuracy: 0.9867 - loss: 1.0193 - precision: 0.9828 - recall: 0.9901 - val_accuracy: 0.8143 - val_binary_accuracy: 0.8143 - val_loss: 1.1266 - val_precision: 1.0000 - val_recall: 0.5738
# Epoch 4/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9576 - binary_accuracy: 0.9576 - loss: 0.7529 - precision: 0.9794 - recall: 0.9336
# Epoch 4: val_loss improved from 1.12662 to 0.89824, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.
20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9926 - binary_accuracy: 0.9926 - loss: 0.2424 - precision: 0.9965 - recall: 0.9880
# Epoch 20: val_loss improved from 0.20102 to 0.19907, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9926 - binary_accuracy: 0.9926 - loss: 0.2423 - precision: 0.9964 - recall: 0.9881 - val_accuracy: 1.0000 - val_binary_accuracy: 1.0000 - val_loss: 0.1991 - val_precision: 1.0000 - val_recall: 1.0000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - binary_accuracy: 1.0000 - loss: 0.1992 - precision: 1.0000 - recall: 1.0000
# Validação - Loss: 0.1991, Accuracy: 1.0000
#
# Fold 10/10
# Epoch 1/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5670 - binary_accuracy: 0.5670 - loss: 6.2274 - precision: 0.5721 - recall: 0.4481
# Epoch 1: val_loss improved from inf to 3.04192, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.5695 - binary_accuracy: 0.5695 - loss: 6.1987 - precision: 0.5764 - recall: 0.4491 - val_accuracy: 0.5143 - val_binary_accuracy: 0.5143 - val_loss: 3.0419 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 35/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9491 - binary_accuracy: 0.9491 - loss: 2.3319 - precision: 0.9480 - recall: 0.9456
# Epoch 2: val_loss improved from 3.04192 to 1.92824, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9490 - binary_accuracy: 0.9490 - loss: 2.2650 - precision: 0.9485 - recall: 0.9453 - val_accuracy: 0.5143 - val_binary_accuracy: 0.5143 - val_loss: 1.9282 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9764 - binary_accuracy: 0.9764 - loss: 1.0555 - precision: 0.9665 - recall: 0.9848
# Epoch 3: val_loss improved from 1.92824 to 1.65138, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9759 - binary_accuracy: 0.9759 - loss: 1.0439 - precision: 0.9659 - recall: 0.9846 - val_accuracy: 0.5143 - val_binary_accuracy: 0.5143 - val_loss: 1.6514 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 35/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9883 - binary_accuracy: 0.9883 - loss: 0.7002 - precision: 0.9860 - recall: 0.9899
# Epoch 4: val_loss improved from 1.65138 to 1.54857, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9866 - binary_accuracy: 0.9866 - loss: 0.6966 - precision: 0.9834 - recall: 0.9889 - val_accuracy: 0.5143 - val_binary_accuracy: 0.5143 - val_loss: 1.5486 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 35/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9733 - binary_accuracy: 0.9733 - loss: 0.5722 - precision: 0.9655 - recall: 0.9825
# Epoch 5: val_loss improved from 1.54857 to 1.15278, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9734 - binary_accuracy: 0.9734 - loss: 0.5680 - precision: 0.9659 - recall: 0.9818 - val_accuracy: 0.5571 - val_binary_accuracy: 0.5571 - val_loss: 1.1528 - val_precision: 1.0000 - val_recall: 0.0882
# Epoch 6/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9887 - binary_accuracy: 0.9887 - loss: 0.4486 - precision: 0.9869 - recall: 0.9898
# Epoch 6: val_loss improved from 1.15278 to 0.86974, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9884 - binary_accuracy: 0.9884 - loss: 0.4489 - precision: 0.9867 - recall: 0.9893 - val_accuracy: 0.6786 - val_binary_accuracy: 0.6786 - val_loss: 0.8697 - val_precision: 1.0000 - val_recall: 0.3382
# Epoch 7/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9789 - binary_accuracy: 0.9789 - loss: 0.4113 - precision: 0.9758 - recall: 0.9827
# Epoch 7: val_loss improved from 0.86974 to 0.66737, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9790 - binary_accuracy: 0.9790 - loss: 0.4106 - precision: 0.9759 - recall: 0.9827 - val_accuracy: 0.8143 - val_binary_accuracy: 0.8143 - val_loss: 0.6674 - val_precision: 1.0000 - val_recall: 0.6176
# Epoch 8/20
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9896 - binary_accuracy: 0.9896 - loss: 0.3167 - precision: 0.9897 - recall: 0.9881
# Epoch 8: val_loss improved from 0.66737 to 0.35304, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9887 - binary_accuracy: 0.9887 - loss: 0.3181 - precision: 0.9887 - recall: 0.9875 - val_accuracy: 0.9786 - val_binary_accuracy: 0.9786 - val_loss: 0.3530 - val_precision: 1.0000 - val_recall: 0.9559
# Epoch 9/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9913 - binary_accuracy: 0.9913 - loss: 0.3085 - precision: 0.9908 - recall: 0.9913
# Epoch 9: val_loss did not improve from 0.35304
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9911 - binary_accuracy: 0.9911 - loss: 0.3091 - precision: 0.9911 - recall: 0.9905 - val_accuracy: 0.9571 - val_binary_accuracy: 0.9571 - val_loss: 0.3832 - val_precision: 1.0000 - val_recall: 0.9118
# Epoch 10/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9884 - binary_accuracy: 0.9884 - loss: 0.3003 - precision: 0.9857 - recall: 0.9909
# Epoch 10: val_loss did not improve from 0.35304
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9882 - binary_accuracy: 0.9882 - loss: 0.3007 - precision: 0.9855 - recall: 0.9908 - val_accuracy: 0.9571 - val_binary_accuracy: 0.9571 - val_loss: 0.3880 - val_precision: 1.0000 - val_recall: 0.9118
# Epoch 11/20
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9905 - binary_accuracy: 0.9905 - loss: 0.2756 - precision: 0.9940 - recall: 0.9877
# Epoch 11: val_loss improved from 0.35304 to 0.27520, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9906 - binary_accuracy: 0.9906 - loss: 0.2749 - precision: 0.9939 - recall: 0.9879 - val_accuracy: 0.9714 - val_binary_accuracy: 0.9714 - val_loss: 0.2752 - val_precision: 1.0000 - val_recall: 0.9412
# Epoch 12/20
# 35/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9860 - binary_accuracy: 0.9860 - loss: 0.2761 - precision: 0.9911 - recall: 0.9799
# Epoch 12: val_loss improved from 0.27520 to 0.21768, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9860 - binary_accuracy: 0.9860 - loss: 0.2772 - precision: 0.9912 - recall: 0.9799 - val_accuracy: 1.0000 - val_binary_accuracy: 1.0000 - val_loss: 0.2177 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 13/20
# 38/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9934 - binary_accuracy: 0.9934 - loss: 0.2387 - precision: 0.9886 - recall: 0.9981
# Epoch 13: val_loss did not improve from 0.21768
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9933 - binary_accuracy: 0.9933 - loss: 0.2382 - precision: 0.9889 - recall: 0.9977 - val_accuracy: 0.9929 - val_binary_accuracy: 0.9929 - val_loss: 0.2917 - val_precision: 0.9855 - val_recall: 1.0000
# Epoch 14/20
# 35/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9877 - binary_accuracy: 0.9877 - loss: 0.2283 - precision: 0.9764 - recall: 0.9996
# Epoch 14: val_loss improved from 0.21768 to 0.20749, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9882 - binary_accuracy: 0.9882 - loss: 0.2288 - precision: 0.9782 - recall: 0.9987 - val_accuracy: 1.0000 - val_binary_accuracy: 1.0000 - val_loss: 0.2075 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 15/20
# 35/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9766 - binary_accuracy: 0.9766 - loss: 0.2820 - precision: 0.9676 - recall: 0.9852
# Epoch 15: val_loss did not improve from 0.20749
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9769 - binary_accuracy: 0.9769 - loss: 0.2815 - precision: 0.9692 - recall: 0.9842 - val_accuracy: 0.9500 - val_binary_accuracy: 0.9500 - val_loss: 0.3608 - val_precision: 1.0000 - val_recall: 0.8971
# Epoch 16/20
# 36/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9811 - binary_accuracy: 0.9811 - loss: 0.2717 - precision: 0.9822 - recall: 0.9790
# Epoch 16: val_loss did not improve from 0.20749
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9814 - binary_accuracy: 0.9814 - loss: 0.2702 - precision: 0.9827 - recall: 0.9792 - val_accuracy: 0.9857 - val_binary_accuracy: 0.9857 - val_loss: 0.2122 - val_precision: 1.0000 - val_recall: 0.9706
# Epoch 17/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9920 - binary_accuracy: 0.9920 - loss: 0.2255 - precision: 0.9901 - recall: 0.9938
# Epoch 17: val_loss improved from 0.20749 to 0.18062, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9920 - binary_accuracy: 0.9920 - loss: 0.2252 - precision: 0.9901 - recall: 0.9938 - val_accuracy: 1.0000 - val_binary_accuracy: 1.0000 - val_loss: 0.1806 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 18/20
# 37/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9890 - binary_accuracy: 0.9890 - loss: 0.2078 - precision: 0.9825 - recall: 0.9949
# Epoch 18: val_loss did not improve from 0.18062
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9889 - binary_accuracy: 0.9889 - loss: 0.2085 - precision: 0.9826 - recall: 0.9945 - val_accuracy: 0.9929 - val_binary_accuracy: 0.9929 - val_loss: 0.1926 - val_precision: 1.0000 - val_recall: 0.9853
# Epoch 19/20
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9867 - binary_accuracy: 0.9867 - loss: 0.2194 - precision: 0.9940 - recall: 0.9792
# Epoch 19: val_loss did not improve from 0.18062
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9869 - binary_accuracy: 0.9869 - loss: 0.2192 - precision: 0.9940 - recall: 0.9796 - val_accuracy: 0.9786 - val_binary_accuracy: 0.9786 - val_loss: 0.2569 - val_precision: 1.0000 - val_recall: 0.9559
# Epoch 20/20
# 39/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9737 - binary_accuracy: 0.9737 - loss: 0.2560 - precision: 0.9787 - recall: 0.9679
# Epoch 20: val_loss improved from 0.18062 to 0.17038, saving model to /checkpoints/implementacao/masculino_doente_saudavel_melhor_modelo.keras
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9741 - binary_accuracy: 0.9741 - loss: 0.2550 - precision: 0.9788 - recall: 0.9685 - val_accuracy: 1.0000 - val_binary_accuracy: 1.0000 - val_loss: 0.1704 - val_precision: 1.0000 - val_recall: 1.0000
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - binary_accuracy: 1.0000 - loss: 0.1706 - precision: 1.0000 - recall: 1.0000
# Validação - Loss: 0.1704, Accuracy: 1.0000
#
# Cross-validation completado.
# Accuracies por fold: [1.0, 1.0, 1.0, 0.9857142567634583, 0.9857142567634583, 1.0, 1.0, 0.9928571581840515, 1.0, 1.0]
# Accuracy média: 0.9964, Desvio padrão: 0.0058

# %%
# Avaliando o modelo no conjunto de teste
histories_teste = []
test_losses = []
test_accuracies = []
test_binary_accuracies = []
test_precisions = []
test_recalls = []

for i in range(10):
    final_model = generate_model()
    # history_final = final_model.fit(X_train_val, y_train_val, epochs=num_epochs, batch_size=batch_size, verbose=1)
    history_final = final_model.fit(X_train_val, y_train_val, epochs=num_epochs, batch_size=batch_size, verbose=1, callbacks=[EarlyStopping(monitor='loss', patience=10, restore_best_weights=True), reduce_lr])
    histories_teste.append(history_final)
    test_loss, test_accuracy, test_binary_accuracy, test_precision, test_recall = final_model.evaluate(X_test, y_test, verbose=0)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
    test_binary_accuracies.append(test_binary_accuracy)
    test_precisions.append(test_precision)
    test_recalls.append(test_recall)
   
    print("Teste ", i + 1)
    print(f"Desempenho no conjunto de teste - Loss: {test_loss:.4f}, Accuracy: {test_accuracy:.4f}, Binary Accuracy: {test_binary_accuracy:.4f}, Precision: {test_precision:.4f}, Recall: {test_recall:.4f}")

print('test_accuracies')
print(test_accuracies)
print()
print('test_binary_accuracies')
print(test_binary_accuracies)
# Out:
# Epoch 1/20
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0
#
# test_binary_accuracies
# [0.996666669845581, 0.996666669845581, 0.9983333349227905, 0.9983333349227905, 0.9883333444595337, 0.9883333444595337, 0.9983333349227905, 0.9983333349227905, 0.9933333396911621, 0.9883333444595337]

# %%
for h in histories:
    print(h.history['accuracy'])

# %%
print(f"Treino: {X_train.shape}, Validação: {X_val.shape}, Teste: {X_test.shape}")

# %%
path_modelos = "D:/mestrado/notebooks/modelos"
final_model.save(path_modelos + "/" + "model_cnn_rnn_masculino.keras")
final_model.save(path_modelos + "/" + "model_cnn_rnn_masculino.h5")
final_model.save_weights(path_modelos + "/" + "model_cnn_rnn_masculino_pesos.weights.h5")

# %%
path_to_save = "/implementacao/model_cnn_rnn_masculino_history_10_fold"

df_concatenado = pd.DataFrame()
for i in range(0, len(histories)):
    df_aux = pd.DataFrame(histories[i].history)
    if( i > 0):
        df_aux = df_aux.rename(columns={"precision_{}".format(i) : "precision", "val_precision_{}".format(i) : "val_precision", "recall_{}".format(i) : "recall", "val_recall_{}".format(i) : "val_recall"})

    df_aux["k_folder"] = i + 1
    df_concatenado = pd.concat([df_concatenado, df_aux], ignore_index=True)

df_concatenado.to_csv("D:/mestrado/notebooks/historicos{}{}".format(path_to_save, ".csv"), index=False)


print("DataFrame com historicos do k_fold salvo em arquivo.csv com sucesso!")

# %%
path_historicos_implementacao = "D:/mestrado/notebooks/historicos/implementacao"

# %%
# Salvar o histórico com pickle
with open(path_historicos_implementacao + '/' + 'model_cnn_rnn_masculino_history_final.pkl', 'wb') as file:
    pickle.dump(history_final.history, file)

# %%
for i in range(k):
    path = path_historicos_implementacao + '/' + 'model_cnn_rnn_masculino_history_fold_' + str(i) + '.pkl'
    with open(path, 'wb') as file:
        pickle.dump(history_final.history, file)

# %% [markdown]
# ### Gráficos

# %%
# Calcular a média e o desvio padrão
mean_train_accuracy = np.mean(train_accuracies, axis=0)
mean_val_accuracy = np.mean(val_accuracies, axis=0)
std_val_accuracy = np.std(val_accuracies, axis=0)

# Plotar as curvas de acurácia
plt.figure(figsize=(10, 6))
plt.plot(mean_train_accuracy, label='Acurácia média no treino', color='navy')
plt.plot(mean_val_accuracy, label='Acurácia média na validação', color='steelblue')
plt.fill_between(range(num_epochs),
                 mean_val_accuracy - std_val_accuracy,
                 mean_val_accuracy + std_val_accuracy,
                 color='steelblue', alpha=0.2, label='Desvio padrão na validação')
plt.title('Acurácias Médias de Treino e Validação ao longo das épocas e folds')
plt.xlabel('Épocas')                                                 
plt.ylabel('Acurácia')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calcular a média e o desvio padrão
mean_train_accuracy = np.mean(train_accuracies, axis=0)
mean_val_accuracy = np.mean(val_accuracies, axis=0)
std_val_accuracy = np.std(val_accuracies, axis=0)

# Plotar as curvas de acurácia
plt.figure(figsize=(10, 6))
plt.plot(mean_train_accuracy, label='Acurácia média no treino', color='navy')
plt.plot(mean_val_accuracy, label='Acurácia média na validação', color='steelblue')
plt.fill_between(range(num_epochs),
                 mean_val_accuracy - std_val_accuracy,
                 mean_val_accuracy + std_val_accuracy,
                 color='steelblue', alpha=0.2, label='Desvio padrão na validação')
#plt.title('Acurácias Médias de Treino e Validação ao longo das épocas e folds')
plt.xlabel('Épocas')                                                 
plt.ylabel('Acurácia')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Interpretação:
#
# A curva de training accuracy mostra como o modelo está aprendendo no conjunto de treino ao longo das épocas.
# A curva de validation accuracy indica o desempenho em dados não vistos (validação).
# Desvio padrão (opcional): A faixa sombreada indica a variação entre os diferentes folds, o que ajuda a avaliar a consistência.

# %%
def plot_training_loss(history, title=True):
    # Verifica se 'loss' está disponível no histórico
    if 'loss' not in history.history:
        print("Loss data not found in history. Check if the metric was included during compilation.")
        return
    
    # Recupera os valores de perda
    losses = history.history['loss']
    
    # Plotar a perda do treino
    plt.figure(figsize=(10, 6))
    plt.plot(losses, label='Perda no treinamento', marker='o', color='firebrick')
    
    # Adicionar os valores de perda no gráfico
    for i, loss in enumerate(losses):
        plt.annotate(f"{loss:.2f}", (i, loss), textcoords="offset points", xytext=(0, 7), ha='center', fontsize=10)
    
    # Configurações do gráfico
    if title:
        plt.title('Perda no Treinamento', fontsize=16)
    plt.xlabel('Épocas', fontsize=14)
    plt.ylabel('Perda', fontsize=14)
    plt.legend(fontsize=10)
    plt.grid(alpha=0.5)
    plt.tight_layout()
    
    # Exibir o gráfico
    plt.show()

# %%
def plot_training_accuracy(history, title = True):
    if 'accuracy' not in history.history:
        print("Accuracy data not found in history. Check if the metric was included during compilation.")
        return

    # Plotar a acurácia do treino
    plt.figure(figsize=(10, 6))
    accuracies = history.history['accuracy']

    # Plotando a curva de acurácia
    plt.plot(accuracies, label='Acurácia no treinamento', marker='o', color='dodgerblue')

    # Adicionar valores de acurácia no gráfico
    for i, acc in enumerate(accuracies):
        plt.annotate(f"{acc:.2f}", (i, acc), textcoords="offset points", xytext=(0, 7), ha='center', fontsize=10)

    # Configurações do gráfico
    if title:
        plt.title('Acurácia no Treinamento', fontsize=16)
    plt.xlabel('Épocas', fontsize=14)
    plt.ylabel('Acurácia', fontsize=14)
    plt.legend(fontsize=10)
    plt.grid(alpha=0.4)
    plt.tight_layout()

    # Exibir o gráfico
    plt.show()

# %%
# Chamar a função com o histórico do treinamento final
plot_training_accuracy(history_final)
plot_training_accuracy(history_final, False)

# Chamar a função com o histórico do treinamento final
plot_training_loss(history_final)
plot_training_loss(history_final, False)

# %%
# Chamar a função com o histórico do treinamento final
plot_training_accuracy(history_final)

# Chamar a função com o histórico do treinamento final
plot_training_loss(history_final)

# %% [markdown]
# Interpretação:
#
# Observe o comportamento do loss durante as épocas:
# Um decaimento gradual e consistente é sinal de um bom ajuste.
# Se o loss oscila ou estaciona cedo, pode ser necessário ajustar hiperparâmetros (como taxa de aprendizado ou regularização).

# %%
# Carregar o histórico salvo com pickle
with open(path_historicos_implementacao + '/' + 'model_cnn_rnn_masculino_history_final.pkl', 'rb') as file:
    loaded_history = pickle.load(file)

print(loaded_history)  # Dicionário com os dados do histórico

# %%
# Prever no conjunto de teste
y_pred = final_model.predict(X_test)
print('y_pred')
print(y_pred)

y_pred_classes = (y_pred > 0.8).astype(int)  # Converter probabilidades para 0 ou 1

# Criar matriz de confusão
cm = confusion_matrix(y_test, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Saudável', 'Patológico'])

# Plotar matriz
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de Confusão')
plt.xlabel('Label Predito')
plt.ylabel('Label Original')
plt.show()

disp.plot(cmap=plt.cm.Oranges)
plt.title('Matriz de Confusão')
plt.xlabel('Label Predito')
plt.ylabel('Label Original')
plt.show()

disp.plot(cmap=plt.cm.Reds)
plt.title('Matriz de Confusão')
plt.xlabel('Label Predito')
plt.ylabel('Label Original')
plt.show()

disp.plot(cmap=plt.cm.Greens)
plt.title('Matriz de Confusão')
plt.xlabel('Label Predito')
plt.ylabel('Label Original')
plt.show()

# %%
def plot_roc_curve(title = True):
    ### Receiver Operating Characteristic (ROC) Curve
    # Calcular curva ROC
    fpr, tpr, thresholds = roc_curve(y_test, y_pred)
    roc_auc = auc(fpr, tpr)

    # Plotar a curva ROC
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='blue', label=f'Curva ROC (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--', label='Classificador aleatório')
    if title:
        plt.title('Curva ROC')
    plt.xlabel('Taxa de Falsos Positivos (FPR)')
    plt.ylabel('Taxa de Verdadeiros Positivos (TPR)')
    plt.legend(loc='lower right')
    plt.show()

# %%
plot_roc_curve()
plot_roc_curve(False)

# %% [markdown]
# Interpretação:
# Curva próxima do canto superior esquerdo: Indica alta performance.
# AUC próximo de 1.0: Excelente desempenho.
# AUC próximo de 0.5: Desempenho igual a um chute aleatório.

# %%
def plot_kfold_accuracy(histories, title = True):
    """
    Plota a curva de acurácia média para treino e validação durante o k-fold cross-validation.

    :param histories: Lista de objetos 'history' retornados por model.fit para cada fold.
    """
    # Inicializar listas para armazenar as métricas de treino e validação
    training_accuracies = []
    validation_accuracies = []

    # Iterar pelos históricos de cada fold
    for history in histories:
        training_accuracies.append(history.history['accuracy'])
        if 'val_accuracy' in history.history:
            validation_accuracies.append(history.history['val_accuracy'])

    # Calcular as médias e desvios padrão por época
    training_accuracies = np.array(training_accuracies)
    validation_accuracies = np.array(validation_accuracies)

    mean_train = np.mean(training_accuracies, axis=0)
    std_train = np.std(training_accuracies, axis=0)
    
    mean_val = np.mean(validation_accuracies, axis=0)
    std_val = np.std(validation_accuracies, axis=0)

    # Plotar as curvas de acurácia
    epochs = range(1, len(mean_train) + 1)
    plt.figure(figsize=(10, 6))
    
    # Acurácia de treino
    plt.plot(epochs, mean_train, label='Acurácia média no treino', color='navy', linewidth=2)
    plt.fill_between(epochs, mean_train - std_train, mean_train + std_train, color='navy', alpha=0.2)
    
    # Acurácia de validação
    plt.plot(epochs, mean_val, label='Acurácia média na validação', color='steelblue', linewidth=2)
    plt.fill_between(epochs, mean_val - std_val, mean_val + std_val, color='steelblue', alpha=0.2)
    
    # Configurações do gráfico
    if title:
        plt.title('Acurácia no 10-Fold Cross-Validation', fontsize=16)
    plt.xlabel('Época', fontsize=14)
    plt.ylabel('Acurácia', fontsize=14)
    plt.legend(fontsize=12)
    plt.grid(True)
    plt.show()

plot_kfold_accuracy(histories)
plot_kfold_accuracy(histories, False)
