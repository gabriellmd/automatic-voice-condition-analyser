# %%
import librosa
import matplotlib.pyplot as plt
import librosa.display as lb_display
import IPython.display as py_display
import numpy as np

from os import listdir, mkdir
from os.path import isfile, join, exists

# %%
general_path = "D:/mestrado/notebooks/dados"
path_svd_a_neutro = join(general_path, "D:/mestrado/notebooks/dados/separacao_a_neutro_doente_saudavel")

path_espectrogramas = join(general_path, "espectrogramas_a_neutro_doente_saudavel")

# %% [markdown]
# ### Extraindo e salvando espectrogramas

# %% [markdown]
# Parâmetros da função *librosa.feature.melspectrogram*
#
# * y = áudio time-serie
# * sr = sample rate. Default: 22050
# * S = spectogram
# * n_fft = length of the FFT window. Default: 2048
# *hop_length = number of samples between successive frames. Default: 512
# * win_length = Length of the window and then padded with eros to match n_fft. Default: win_length = n_fft
# * window = window function
# * center. Default = 'True'
# * pad_mode = Default:'constant'
# * power = magnitude melspectogram. Default: 2
# * n_mels = number of mel band to generate
# * fmin = lowest frequency
# *  fmax = highest frequency. Default: 'None' -> sr/2.0
#
# **librosa.feature.melspectogram gera mesmo resultado de extrair o stft e elevar ao quadrado**

# %%
### funcao para ler arquivo, extrair espectrograma e salvar

def gerar_espectrograma(audio_path, path_to_save, img_extension):
    # sr default = sr do audio original = 22050
    audio_data, sr = librosa.load(audio_path)
    mel_spectrogram = librosa.feature.melspectrogram(y=audio_data, sr=sr)

    # Convert a power spectrogram (amplitude squared) to decibel (dB) units
    # ref: the amplitude is scaled to the number passed
    # return: S_db ~= 10 * log10(S) - 10 * log10(ref)
    mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)

    # cmap = colormap for plotting the spectrogram
    # y_axis = 'mel': frequencies are determined by the mel scale
    # y_axis = 'log': the spectrum is displayed on a log scale
    plt.rcParams["figure.autolayout"] = True
    plt.rcParams["savefig.bbox"] = 'tight'

    plt.figure(figsize=(10,4))
    librosa.display.specshow(mel_spectrogram_db, x_axis=None, y_axis=None, sr=sr, cmap=None)
    plt.savefig(path_to_save.split(".")[0] + "." + img_extension, bbox_inches = 'tight', pad_inches = 0)
    plt.close()
    print("Arquivo " + path_to_save.split(".")[0] + "." + img_extension + " salvo com sucesso!")

# %%
def create_dir(dir_path):
    try:
        print("Criando pasta: " + dir_path)
        mkdir(dir_path)
    except OSError as error:
        print(error)
        print()

# %%
####################### usado para pasta separacao_svd_a_neutro_doente_saudavel
create_dir(path_espectrogramas)

categorias = [a for a in listdir(path_svd_a_neutro) if not isfile(join(path_svd_a_neutro, a))]
print("Categorias: " + ", ".join(categorias))
print()

for c in categorias:
    print("======================================================================")
    print("Pasta: " + c)
    path_c = join(path_svd_a_neutro, c)
    path_c_espec = join(path_espectrogramas, c)
    if not exists(path_c_espec):
        create_dir(path_c_espec)

    for arquivo in  listdir(path_c):
            path_file = join(path_c, arquivo)
            path_file_espec = join(path_c_espec, arquivo)

            print("Extraindo espectrograma do áudio: " + arquivo + " ...")
            gerar_espectrograma(path_file, path_file_espec, "png")
            
    print("===================> Fim da categoria: " + c + " <====================")
    print()
# Out:
# Criando pasta: D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel
# Categorias: masculino, feminino
#
# ======================================================================
# Pasta: masculino
# Criando pasta: D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino
# Extraindo espectrograma do áudio: 916-disfonia_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\916-disfonia_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 925-disfonia_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\925-disfonia_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1086-disfonia_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\1086-disfonia_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 
saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\694-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 698-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\698-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 701-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\701-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 704-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\704-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 706-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\706-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 708-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\708-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 739-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\739-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 740-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\740-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 744-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\744-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 782-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\782-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 803-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\803-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 804-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\804-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 805-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\805-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 806-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\806-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 807-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\807-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 808-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\808-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 809-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\809-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 810-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\810-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 811-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\811-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 812-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\812-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 813-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\813-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 860-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\860-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 861-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\861-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 862-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\862-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 941-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\941-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 942-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\942-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 943-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\943-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 945-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\945-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 946-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\946-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 947-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\947-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 948-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\948-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 949-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\949-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 950-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\950-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 951-saudavel_m_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\masculino\951-saudavel_m_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 952-saudavel_m_a_neutro.wav ...
# ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\836-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 837-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\837-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 838-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\838-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 839-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\839-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 840-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\840-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 841-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\841-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 842-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\842-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 843-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\843-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 852-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\852-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 865-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\865-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 867-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\867-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 944-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\944-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 962-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\962-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 990-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\990-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1006-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1006-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1022-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1022-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1024-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1024-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1029-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1029-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1059-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1059-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1060-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1060-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1065-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1065-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1066-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1066-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1067-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1067-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1068-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1068-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1094-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1094-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1095-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1095-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1096-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1096-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1097-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1097-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1098-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1098-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1099-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1099-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1100-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1100-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1101-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1101-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1102-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1102-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1103-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1103-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1104-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1104-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1105-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1105-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1106-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1106-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1107-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1107-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1109-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1109-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1110-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1110-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1112-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1112-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1121-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1121-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1122-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1122-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1123-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1123-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1124-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1124-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1127-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1127-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1128-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1128-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1129-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1129-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1130-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1130-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1131-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1131-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1132-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1132-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1133-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1133-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1134-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1134-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1135-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1135-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1137-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1137-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1139-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1139-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1144-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1144-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1145-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1145-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1146-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1146-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1147-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1147-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1148-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1148-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1149-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1149-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1150-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1150-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1151-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1151-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1167-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1167-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1168-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1168-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1169-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1169-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1170-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1170-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1171-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1171-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1172-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1172-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1174-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1174-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1175-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1175-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1176-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1176-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1177-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1177-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1178-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1178-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1179-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1179-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1180-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1180-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1182-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1182-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1184-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1184-saudavel_f_a_neutro.png salvo com sucesso!
# Extraindo espectrograma do áudio: 1185-saudavel_f_a_neutro.wav ...
# Arquivo D:/mestrado/notebooks/dados\espectrogramas_a_neutro_doente_saudavel\feminino\1185-saudavel_f_a_neutro.png salvo com sucesso!
# ===================> Fim da categoria: feminino <====================

# %%
####################### usado para pasta svd_a_3_tons_doente_saudavel
path_espectrogramas = "D:/mestrado/notebooks/dados/espectrogramas_a_3_tons"
create_dir(path_espectrogramas)
path_svd_a_3_tons_doente_saudavel = "D:/mestrado/notebooks/dados/svd_a_3_tons_doente_saudavel"
categorias = [a for a in listdir(path_svd_a_3_tons_doente_saudavel) if not isfile(join(path_svd_a_3_tons_doente_saudavel, a))]
print("Categorias: " + ", ".join(categorias))
print()

for c in categorias:
    print("======================================================================")
    print("Pasta: " + c)
    path_c = join(path_svd_a_3_tons_doente_saudavel, c)
    path_c_espec = join(path_espectrogramas, c)
    if not exists(path_c_espec):
        create_dir(path_c_espec)

    for arquivo in  listdir(path_c):
            path_file = join(path_c, arquivo)
            path_file_espec = join(path_c_espec, arquivo)

            print("Extraindo espectrograma do áudio: " + arquivo + " ...")
            gerar_espectrograma(path_file, path_file_espec, "png")
            
    print("===================> Fim da categoria: " + c + " <====================")
    print()
# Out:
# Criando pasta: D:/mestrado/notebooks/dados/espectrogramas_a_3_tons
# [WinError 183] Não é possível criar um arquivo já existente: 'D:/mestrado/notebooks/dados/espectrogramas_a_3_tons'
#
# Categorias: masculino, feminino
#
# ======================================================================
# Pasta: masculino
# Criando pasta: D:/mestrado/notebooks/dados/espectrogramas_a_3_tons\mascul